# %% [markdown]
# # Exploring DataSAIL and BACE Dataset
#
# **Goal:** Understand DataSAIL's interface and establish baseline performance.
#
# ## Tasks:
# 1. Load BACE dataset
# 2. Explore data structure
# 3. Run DataSAIL split
# 4. Understand output format and leakage metrics

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import time

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

print("Imports successful!")

# %% [markdown]
# ## 1. Load BACE Dataset

# %%
# Load dataset
data_path = Path("../data/raw/moleculenet/bace.csv")
df = pd.read_csv(data_path)

print(f"Dataset shape: {df.shape}")
print(f"\nColumns: {list(df.columns)}")
print(f"\nFirst few rows:")
df.head()

# %% [markdown]
# ## 2. Explore Label Distribution

# %%
# Check for label column
label_col = 'Class' if 'Class' in df.columns else 'pIC50'
print(f"Label column: {label_col}")
print(f"\nLabel distribution:")
print(df[label_col].value_counts())

# Visualize
plt.figure(figsize=(8, 5))
df[label_col].value_counts().plot(kind='bar')
plt.title('BACE Dataset Label Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Next Steps
#
# TODO:
# - Study DataSAIL documentation
# - Figure out how to run a split programmatically
# - Time the execution
# - Extract leakage metrics
